# %% [markdown]
# <a href="https://colab.research.google.com/github/uttamtyagi01/Python-libraries/blob/main/Lab_2_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "RollNo": [101, 102, 103, 104, 105, 106, 107, 108],
    "Name": [
        "Amit", "Neha", "Rahul", "Priya",
        "Rohan", "Kavya", "Arjun", "Simran"
    ],
    "Department": [
        "BCA", "BCA", "MCA", "BCA",
        "MCA", "MCA", "BCA", "MCA"
    ],
    "Age": [20, 21, 22, 20, 23, 22, 21, 24],
    "Marks": [85, 92, 67, 78, 88, 95, 55, 73]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    RollNo    Name Department  Age  Marks
# 0     101    Amit        BCA   20     85
# 1     102    Neha        BCA   21     92
# 2     103   Rahul        MCA   22     67
# 3     104   Priya        BCA   20     78
# 4     105   Rohan        MCA   23     88
# 5     106   Kavya        MCA   22     95
# 6     107   Arjun        BCA   21     55
# 7     108  Simran        MCA   24     73

# %%
print(df.head(3))
# Out:
#    RollNo   Name Department  Age  Marks
# 0     101   Amit        BCA   20     85
# 1     102   Neha        BCA   21     92
# 2     103  Rahul        MCA   22     67

# %%
print(df.tail(2))
# Out:
#    RollNo    Name Department  Age  Marks
# 6     107   Arjun        BCA   21     55
# 7     108  Simran        MCA   24     73

# %%
rows, columns = df.shape

print("Number of rows:", rows)
print("Number of columns:", columns)
# Out:
# Number of rows: 8
# Number of columns: 5

# %%
print(df.columns)
# Out:
# Index(['RollNo', 'Name', 'Department', 'Age', 'Marks'], dtype='object')

# %%
print(df.dtypes)
# Out:
# RollNo         int64
# Name          object
# Department    object
# Age            int64
# Marks          int64
# dtype: object

# %%
print(df["Name"])
# Out:
# 0      Amit
# 1      Neha
# 2     Rahul
# 3     Priya
# 4     Rohan
# 5     Kavya
# 6     Arjun
# 7    Simran
# Name: Name, dtype: object

# %%
print(df[["Name", "Marks"]])
# Out:
#      Name  Marks
# 0    Amit     85
# 1    Neha     92
# 2   Rahul     67
# 3   Priya     78
# 4   Rohan     88
# 5   Kavya     95
# 6   Arjun     55
# 7  Simran     73

# %%
print(df[df["Marks"] > 80])
# Out:
#    RollNo   Name Department  Age  Marks
# 0     101   Amit        BCA   20     85
# 1     102   Neha        BCA   21     92
# 4     105  Rohan        MCA   23     88
# 5     106  Kavya        MCA   22     95

# %%
print(df[df["Marks"] < 70])
# Out:
#    RollNo   Name Department  Age  Marks
# 2     103  Rahul        MCA   22     67
# 6     107  Arjun        BCA   21     55

# %%
print(df[(df["Marks"] >= 70) & (df["Marks"] <= 90)])
# Out:
#    RollNo    Name Department  Age  Marks
# 0     101    Amit        BCA   20     85
# 3     104   Priya        BCA   20     78
# 4     105   Rohan        MCA   23     88
# 7     108  Simran        MCA   24     73

# %%
print(df[df["Department"] == "BCA"])
# Out:
#    RollNo   Name Department  Age  Marks
# 0     101   Amit        BCA   20     85
# 1     102   Neha        BCA   21     92
# 3     104  Priya        BCA   20     78
# 6     107  Arjun        BCA   21     55

# %%
print(df[(df["Department"] == "MCA") & (df["Marks"] > 80)])
# Out:
#    RollNo   Name Department  Age  Marks
# 4     105  Rohan        MCA   23     88
# 5     106  Kavya        MCA   22     95

# %%
print(df[df["Age"] > 21])
# Out:
#    RollNo    Name Department  Age  Marks
# 2     103   Rahul        MCA   22     67
# 4     105   Rohan        MCA   23     88
# 5     106   Kavya        MCA   22     95
# 7     108  Simran        MCA   24     73

# %%
print("Average Marks:", df["Marks"].mean())
# Out:
# Average Marks: 79.125

# %%
print("Maximum Marks:", df["Marks"].max())
# Out:
# Maximum Marks: 95

# %%
print("Minimum Marks:", df["Marks"].min())
# Out:
# Minimum Marks: 55

# %%
print("Median Marks:", df["Marks"].median())
# Out:
# Median Marks: 81.5

# %%
print("Students scoring above 75:", (df["Marks"] > 75).sum())
# Out:
# Students scoring above 75: 5

# %%
bca_avg = df[df["Department"] == "BCA"]["Marks"].mean()
print("Average BCA Marks:", bca_avg)
# Out:
# Average BCA Marks: 77.5

# %%
mca_avg = df[df["Department"] == "MCA"]["Marks"].mean()
print("Average MCA Marks:", mca_avg)
# Out:
# Average MCA Marks: 80.75

# %%
highest_student = df.loc[df["Marks"].idxmax()]

print("Highest-Scoring Student:")
print(highest_student)
# Out:
# Highest-Scoring Student:
# RollNo          106
# Name          Kavya
# Department      MCA
# Age              22
# Marks            95
# Name: 5, dtype: object

# %%
df["Result"] = df["Marks"].apply(
    lambda x: "Pass" if x >= 40 else "Fail"
)

print(df)
# Out:
#    RollNo    Name Department  Age  Marks Result
# 0     101    Amit        BCA   20     85   Pass
# 1     102    Neha        BCA   21     92   Pass
# 2     103   Rahul        MCA   22     67   Pass
# 3     104   Priya        BCA   20     78   Pass
# 4     105   Rohan        MCA   23     88   Pass
# 5     106   Kavya        MCA   22     95   Pass
# 6     107   Arjun        BCA   21     55   Pass
# 7     108  Simran        MCA   24     73   Pass

# %%
df["Marks"] = df["Marks"] + 5

print(df)
# Out:
#    RollNo    Name Department  Age  Marks Result
# 0     101    Amit        BCA   20     90   Pass
# 1     102    Neha        BCA   21     97   Pass
# 2     103   Rahul        MCA   22     72   Pass
# 3     104   Priya        BCA   20     83   Pass
# 4     105   Rohan        MCA   23     93   Pass
# 5     106   Kavya        MCA   22    100   Pass
# 6     107   Arjun        BCA   21     60   Pass
# 7     108  Simran        MCA   24     78   Pass

# %%
df = df.drop(columns=["Age"])

print(df)
# Out:
#    RollNo    Name Department  Marks Result
# 0     101    Amit        BCA     90   Pass
# 1     102    Neha        BCA     97   Pass
# 2     103   Rahul        MCA     72   Pass
# 3     104   Priya        BCA     83   Pass
# 4     105   Rohan        MCA     93   Pass
# 5     106   Kavya        MCA    100   Pass
# 6     107   Arjun        BCA     60   Pass
# 7     108  Simran        MCA     78   Pass

# %%
df = df.rename(columns={"Marks": "Score"})

print(df)
# Out:
#    RollNo    Name Department  Score Result
# 0     101    Amit        BCA     90   Pass
# 1     102    Neha        BCA     97   Pass
# 2     103   Rahul        MCA     72   Pass
# 3     104   Priya        BCA     83   Pass
# 4     105   Rohan        MCA     93   Pass
# 5     106   Kavya        MCA    100   Pass
# 6     107   Arjun        BCA     60   Pass
# 7     108  Simran        MCA     78   Pass

# %%
print(df.sort_values(by="Score"))
# Out:
#    RollNo    Name Department  Score Result
# 6     107   Arjun        BCA     60   Pass
# 2     103   Rahul        MCA     72   Pass
# 7     108  Simran        MCA     78   Pass
# 3     104   Priya        BCA     83   Pass
# 0     101    Amit        BCA     90   Pass
# 4     105   Rohan        MCA     93   Pass
# 1     102    Neha        BCA     97   Pass
# 5     106   Kavya        MCA    100   Pass

# %%
print(df.sort_values(by="Score", ascending=False))
# Out:
#    RollNo    Name Department  Score Result
# 5     106   Kavya        MCA    100   Pass
# 1     102    Neha        BCA     97   Pass
# 4     105   Rohan        MCA     93   Pass
# 0     101    Amit        BCA     90   Pass
# 3     104   Priya        BCA     83   Pass
# 7     108  Simran        MCA     78   Pass
# 2     103   Rahul        MCA     72   Pass
# 6     107   Arjun        BCA     60   Pass

# %%
print(df.sort_values(by="Score", ascending=False).head(3))
# Out:
#    RollNo   Name Department  Score Result
# 5     106  Kavya        MCA    100   Pass
# 1     102   Neha        BCA     97   Pass
# 4     105  Rohan        MCA     93   Pass

# %%
print(df.groupby("Department")["Score"].mean())
# Out:
# Department
# BCA    82.50
# MCA    85.75
# Name: Score, dtype: float64

# %%
print(df.groupby("Department")["Score"].max())
# Out:
# Department
# BCA     97
# MCA    100
# Name: Score, dtype: int64

# %%
print(df.groupby("Department")["Score"].min())
# Out:
# Department
# BCA    60
# MCA    72
# Name: Score, dtype: int64

# %%
print(df["Department"].value_counts())
# Out:
# Department
# BCA    4
# MCA    4
# Name: count, dtype: int64

# %%
# Create Grade
def calculate_grade(marks):
    if marks >= 90:
        return "A+"
    elif marks >= 80:
        return "A"
    elif marks >= 70:
        return "B"
    elif marks >= 60:
        return "C"
    elif marks >= 50:
        return "D"
    else:
        return "F"


# Create Grade column
df["Grade"] = df["Score"].apply(calculate_grade)

# Sort by Marks/Score: highest to lowest
merit_list = df.sort_values(by="Score", ascending=False).copy()

# Add Rank
merit_list["Rank"] = range(1, len(merit_list) + 1)

# Select required columns
merit_list = merit_list[
    ["Rank", "RollNo", "Name", "Department", "Score", "Grade", "Result"]
]

# Rename Score back to Marks for final merit list
merit_list = merit_list.rename(columns={"Score": "Marks"})

# Display final merit list
print(merit_list)
# Out:
#    Rank  RollNo    Name Department  Marks Grade Result
# 5     1     106   Kavya        MCA    100    A+   Pass
# 1     2     102    Neha        BCA     97    A+   Pass
# 4     3     105   Rohan        MCA     93    A+   Pass
# 0     4     101    Amit        BCA     90    A+   Pass
# 3     5     104   Priya        BCA     83     A   Pass
# 7     6     108  Simran        MCA     78     B   Pass
# 2     7     103   Rahul        MCA     72     B   Pass
# 6     8     107   Arjun        BCA     60     C   Pass

# %%
merit_list.to_excel("student_merit_list.xlsx", index=False)

print("Merit list exported successfully!")
# Out:
# Merit list exported successfully!

# %%
from google.colab import files

files.download("student_merit_list.xlsx")
