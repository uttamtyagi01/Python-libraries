# %% [markdown]
# <a href="https://colab.research.google.com/github/uttamtyagi01/Python-libraries/blob/main/NUMPY_PRACTICE_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
marks=np.array([24,67,83,95])
print(marks)
# Out:
# [24 67 83 95]

# %%
print(type(marks))
# Out:
# <class 'numpy.ndarray'>

# %%
marks=np.array([57,89,76,54])
print(marks+5)
# Out:
# [62 94 81 59]

# %%
print(marks.shape)
# Out:
# (4,)

# %%
print(marks.size)
# Out:
# 4

# %%
print(marks.dtype)
# Out:
# int64

# %%
numbers=np.array([10,20,30,40,50])
print(numbers)
# Out:
# [10 20 30 40 50]

# %%
print(type(numbers))
# Out:
# <class 'numpy.ndarray'>

# %%
print(numbers.shape)
# Out:
# (5,)

# %%
print(numbers.size)
# Out:
# 5

# %%
print(numbers.dtype)
# Out:
# int64

# %%
print(numbers+10)
# Out:
# [20 30 40 50 60]

# %%
print(numbers*2)
# Out:
# [ 20  40  60  80 100]

# %%
salaries=np.array([25000,30000,40000,50000,60000])
print(salaries)
# Out:
# [25000 30000 40000 50000 60000]

# %%
total=np.sum(salaries)
average=np.mean(salaries)
print(total)
print(average)
# Out:
# 205000
# 41000.0
